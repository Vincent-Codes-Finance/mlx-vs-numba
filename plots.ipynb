# %%
import pandas as pd

df = pd.read_csv("times.csv")

# %%
df[df["t"]==250].set_index("n").groupby("library")["time"].plot(legend=True, logy=True, logx=True);

# %%
df[df["t"]==500].set_index("n").groupby("library")["time"].plot(legend=True, logy=True, logx=True);
